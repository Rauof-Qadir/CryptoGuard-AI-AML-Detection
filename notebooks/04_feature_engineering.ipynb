# %%
import pandas as pd


data = pd.read_csv(
"../data/processed/elliptic_clean.csv"
)


data.head()
# Out:
#        time  feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0 -1.556878   0.307025   1.168821  -0.748109   7.643807  -0.053406   6.039024
# 1 -1.556878   0.067780   0.271911  -0.226081   2.628539  -0.053406   2.820415
# 2 -1.556878  -0.135517  -0.222646  -1.270138  -0.183761  -0.041930  -0.187137
# 3 -1.556878  -0.140505  -0.222646  -1.270138  -0.183761  -0.041930  -0.187137
# 4 -1.556878  -0.170324  -0.222646  -1.270138  -0.090018  -0.041930  -0.134373
#
#    feature_7  feature_8  feature_9  ...  feature_157  feature_158  \
# 0  21.528480  -0.146334  -0.084347  ...    -0.619017     0.155526
# 1   1.501088  -0.146334  -0.127352  ...    -0.619017     0.155526
# 2  -0.080022  -0.102664  -0.126685  ...    -0.619017     0.155526
# 3  -0.080022  -0.108753  -0.131978  ...    -0.586053    -1.091739
# 4   0.447015  -0.146324  -0.164128  ...    -0.605832     0.155526
#
#    feature_159  feature_160  feature_161  feature_162  feature_163  \
# ...

# %%
from pathlib import Path
import sys

# Locate the project root from the notebook's working directory
project_root = Path.cwd()
while project_root != project_root.parent and not (project_root / "src").is_dir():
    project_root = project_root.parent

if not (project_root / "src").is_dir():
    raise FileNotFoundError("Could not locate the project 'src' directory.")

sys.path.insert(0, str(project_root))

from src.feature_engineering import create_behavior_features

# %%
feature_input = data.copy()

if "txId" not in feature_input.columns:
    feature_input.insert(
        0,
        "txId",
        range(len(feature_input))
    )

aml_data = create_behavior_features(feature_input)

aml_data.head()


aml_data.head()
# Out:
#    txId      time  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0     0 -1.556878   0.307025   1.168821  -0.748109   7.643807  -0.053406
# 1     1 -1.556878   0.067780   0.271911  -0.226081   2.628539  -0.053406
# 2     2 -1.556878  -0.135517  -0.222646  -1.270138  -0.183761  -0.041930
# 3     3 -1.556878  -0.140505  -0.222646  -1.270138  -0.183761  -0.041930
# 4     4 -1.556878  -0.170324  -0.222646  -1.270138  -0.090018  -0.041930
#
#    feature_6  feature_7  feature_8  ...  feature_160  feature_161  \
# 0   6.039024  21.528480  -0.146334  ...     2.115930     0.016322
# 1   2.820415   1.501088  -0.146334  ...     1.200416    -0.028141
# 2  -0.187137  -0.080022  -0.102664  ...     0.056025    -0.083719
# 3  -0.187137  -0.080022  -0.108753  ...     0.056025    -0.083719
# 4  -0.134373   0.447015  -0.146324  ...     0.056025    -0.072604
#
#    feature_162  feature_163  feature_164  feature_165  class  \
# 0    -0.117599     0.593442     -0.08332    -0.082052      2
# ...

# %%
aml_data.to_csv(
"../data/processed/aml_features.csv",
index=False
)
