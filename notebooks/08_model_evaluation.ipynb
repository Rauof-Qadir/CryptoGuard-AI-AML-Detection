# %%
import pandas as pd


data = pd.read_csv(
    "../data/processed/fraud_detection_results.csv"
)


data.head()
# Out:
#    txId      time  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0     0 -1.556878   0.307025   1.168821  -0.748109   7.643807  -0.053406
# 1     1 -1.556878   0.067780   0.271911  -0.226081   2.628539  -0.053406
# 2     2 -1.556878  -0.135517  -0.222646  -1.270138  -0.183761  -0.041930
# 3     3 -1.556878  -0.140505  -0.222646  -1.270138  -0.183761  -0.041930
# 4     4 -1.556878  -0.170324  -0.222646  -1.270138  -0.090018  -0.041930
#
#    feature_6  feature_7  feature_8  ...  feature_164  feature_165  class  \
# 0   6.039024  21.528480  -0.146334  ...     -0.08332    -0.082052      2
# 1   2.820415   1.501088  -0.146334  ...     -0.08332    -0.082052      2
# 2  -0.187137  -0.080022  -0.102664  ...     -0.08332    -0.082052      2
# 3  -0.187137  -0.080022  -0.108753  ...     -0.08332    -0.082052      2
# 4  -0.134373   0.447015  -0.146324  ...     -1.72568    -1.726407      2
#
#    transaction_velocity  night_transaction  high_amount_flag  anomaly  \
# 0                  2147                  0                 0        1
# 1                  2147                  0                 0        1
# 2                  2147                  0                 0        1
# 3                  2147                  0                 0        1
# 4                  2147                  0                 0        1
#
#    is_suspicious  risk_score  risk_level
# 0          False          30         LOW
# 1          False          30         LOW
# 2          False          30         LOW
# 3          False          30         LOW
# 4          False          30         LOW
#
# [5 rows x 175 columns]

# %%
y_true = data["class"]

y_pred = data["anomaly"]

# %%
y_pred = y_pred.replace(
    {
        1:0,
        -1:1
    }
)

# %%
from sklearn.metrics import (
    classification_report,
    confusion_matrix
)


print(
classification_report(
    y_true,
    y_pred
)
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       0.0
#            1       0.00      0.00      0.00    4545.0
#            2       0.00      0.00      0.00   42019.0
#
#     accuracy                           0.00   46564.0
#    macro avg       0.00      0.00      0.00   46564.0
# weighted avg       0.00      0.00      0.00   46564.0
# c:\Users\Hp\Desktop\CryptoGuard-AI-AML-Detection\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Hp\Desktop\CryptoGuard-AI-AML-Detection\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Hp\Desktop\CryptoGuard-AI-AML-Detection\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Hp\Desktop\CryptoGuard-AI-AML-Detection\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Hp\Desktop\CryptoGuard-AI-AML-Detection\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Hp\Desktop\CryptoGuard-AI-AML-Detection\venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import matplotlib.pyplot as plt
import seaborn as sns


cm = confusion_matrix(
    y_true,
    y_pred
)


sns.heatmap(
    cm,
    annot=True,
    fmt="d"
)


plt.xlabel(
"Prediction"
)

plt.ylabel(
"Actual"
)

plt.title(
"AML Detection Confusion Matrix"
)

plt.show()
