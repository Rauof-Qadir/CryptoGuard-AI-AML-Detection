# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(
"../data/raw/transactions.csv"
)

# %%
df.head()
# Out:
#   transaction_id  wallet_id  amount                   timestamp   country  \
# 0            TX0  WALLET003     208  2026-08-28 20:46:32.271973  Pakistan
# 1            TX1  WALLET004  158051  2026-02-12 20:46:32.272014        UK
# 2            TX2  WALLET002    1562  2026-09-18 20:46:32.272025        UK
# 3            TX3  WALLET005    3715  2025-12-28 20:46:32.272032    Russia
# 4            TX4  WALLET003    3265  2025-10-28 20:46:32.272038    Russia
#
#    merchant  wallet_age_days  previous_transactions
# 0  Coinbase              178                    333
# 1    Kraken              206                    133
# 2  Coinbase              690                    383
# 3    Kraken              664                    372
# 4  Coinbase              832                    177

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   transaction_id         1000 non-null   str
#  1   wallet_id              1000 non-null   str
#  2   amount                 1000 non-null   int64
#  3   timestamp              1000 non-null   str
#  4   country                1000 non-null   str
#  5   merchant               1000 non-null   str
#  6   wallet_age_days        1000 non-null   int64
#  7   previous_transactions  1000 non-null   int64
# dtypes: int64(3), str(5)
# memory usage: 113.5 KB

# %%
df.describe()
# Out:
#               amount  wallet_age_days  previous_transactions
# count    1000.000000      1000.000000            1000.000000
# mean     9070.129000       499.385000             260.446000
# std     28955.752327       291.768246             144.312776
# min        22.000000         1.000000               0.000000
# 25%      1431.250000       234.750000             137.000000
# 50%      2738.000000       517.500000             271.000000
# 75%      3992.000000       749.250000             382.250000
# max    199491.000000      1000.000000             500.000000

# %%
plt.figure(figsize=(8,5))

sns.histplot(
df["amount"],
bins=50
)

plt.title(
"Transaction Amount Distribution"
)

plt.show()
